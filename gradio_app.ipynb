# %%
2+2
# Out:
# 4

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /Users/rajesh/miniconda3/lib/python3.13/site-packages (5.49.1)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (4.10.0)
# Requirement already satisfied: audioop-lts<1.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.2.1)
# Requirement already satisfied: brotli>=1.1.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.120.4)
# Requirement already satisfied: ffmpy in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (11.3.0)
# Collecting pydantic<2.12,>=2.0 (from gradio)
#   Downloading pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: pydub in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.14.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.18.0)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio) (0.36.0)
# Requirement already satisfied: fsspec in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio-client==1.13.3->gradio) (2025.9.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.3)
# Requirement already satisfied: certifi in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.19.1)
# Requirement already satisfied: requests in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.69.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.1.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio)
#   Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rajesh/miniconda3/lib/python3.13/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.7.0)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: pydantic-core, aiofiles, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.5
#     Uninstalling pydantic_core-2.41.5:
#       Successfully uninstalled pydantic_core-2.41.5
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 25.1.0
#     Uninstalling aiofiles-25.1.0:
#       Successfully uninstalled aiofiles-25.1.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.5
#     Uninstalling pydantic-2.12.5:
#       Successfully uninstalled pydantic-2.12.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pydantic]━━━━━━━━━ 2/3 [pydantic]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.1.53 which is incompatible.
# langchain-classic 1.0.0 requires langchain-text-splitters<2.0.0,>=1.0.0, but you have langchain-text-splitters 0.0.2 which is incompatible.
# unstructured-client 0.45.0 requires aiofiles>=25.1.0, but you have aiofiles 24.1.0 which is incompatible.
# unstructured-client 0.45.0 requires pydantic>=2.12.5, but you have pydantic 2.11.10 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.1.53 which is incompatible.
# langgraph-checkpoint 4.1.1 requires langchain-core>=0.2.38, but you have langchain-core 0.1.53 which is incompatible.
# langgraph 1.2.9 requires langchain-core<2,>=1.4.7, but you have langchain-core 0.1.53 which is incompatible.
# qdrant-client 1.16.1 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.4 which is incompatible.
# litellm 1.83.4 requires openai==2.30.0, but you have openai 2.46.0 which is incompatible.
# litellm 1.83.4 requires pydantic==2.12.5, but you have pydantic 2.11.10 which is incompatible.
# langchain-openai 1.0.1 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.1.53 which is incompatible.
# langchain-chroma 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.1.53 which is incompatible.
# langchain-chroma 1.0.0 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.4 which is incompatible.
# Successfully installed aiofiles-24.1.0 pydantic-2.11.10 pydantic-core-2.33.2

# %%
import gradio as gr

# %%
def greet(name):
    """Simple greeting function"""
    return f"Hello, {name}! Welcome to Gradio."

# %%
greet("rajesh")
# Out:
# 'Hello, rajesh! Welcome to Gradio.'

# %%
greet("Priya")
# Out:
# 'Hello, Priya! Welcome to Gradio.'

# %%
demo_1 = gr.Interface(
    fn=greet,
    inputs="text",
    outputs="text",
    title= "My first Gradio APP"
)


demo_1.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://61d0425847de38b3dc.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://61d0425847de38b3dc.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def calculate_bmi(weight, height):
    """Calculate BMI and return classification"""
    bmi = weight / (height ** 2)
    
    if bmi < 18.5:
        category = "Underweight"
    elif bmi < 25:
        category = "Normal weight"
    elif bmi < 30:
        category = "Overweight"
    else:
        category = "Obese"
    
    return round(bmi, 2), category

# %%
demo_2 = gr.Interface(
    fn=calculate_bmi,
    inputs=[
        gr.Number(label="Weight (KG)", value = 70),
        gr.Number(label="Height (mt)", value = 1.75),
    ],

    outputs=[
        gr.Number(label="BMI"),
        gr.Text(label="Category"),
    ],
    title= "Rajesh BMI Calculator"
)
demo_2.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://86d558cc2118cec130.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://86d558cc2118cec130.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
s = "My name is anthony gonsalvis"
s.split()
# Out:
# ['My', 'name', 'is', 'anthony', 'gonsalvis']

# %%
def analyze_text(text, case_option, word_limit):
    """Analyze and transform text based on options"""
    word_limit=int(word_limit)
    if not text:
        return "Please enter some text", 0, []
    
    # Apply case transformation
    if case_option == "Upper":
        transformed = text.upper()
    elif case_option == "Lower":
        transformed = text.lower()
    elif case_option == "Title":
        transformed = text.title()
    else:
        transformed = text

    # Count words
    words = text.split()
    word_count = len(words)
    
    
    # Get limited words
    limited_words = words[:word_limit] if word_limit > 0 else words
    
    return transformed, word_count, limited_words

# %%
analyze_text("rajesh thakur", "Title", 1)
# Out:
# ('Rajesh Thakur', 2, ['rajesh'])

# %%
demo3 = gr.Interface(
    fn=analyze_text,
    inputs=[
        gr.Textbox(label="Input Text", lines=3, placeholder="Enter your text here..."),
        gr.Dropdown(["Original", "Upper", "Lower", "Title"], label="Case Transform"),
        gr.Slider(1, 20, value=3, label="Word Limit")
    ],

    outputs=[
        gr.Textbox(label="Transformed Text"),
        gr.Number(label="Word Count"),
        gr.JSON(label="Limited Words")
    ],

    title="Text Analyzer"
)

demo3.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# ============================================================================
# STEP 5: Image Processing
# ============================================================================

import numpy as np
def simple_image_filter(image, filter_type):
    """Apply simple filters to images"""
    if image is None:
        return None
    
    # Convert to numpy array
    img_array = np.array(image)
    
    if filter_type == "Grayscale":
        # Convert to grayscale
        gray = np.dot(img_array[...,:3], [0.299, 0.587, 0.114])
        return np.stack([gray, gray, gray], axis=-1).astype(np.uint8)
    
    elif filter_type == "Red Channel":
        # Keep only red channel
        red_only = img_array.copy()
        red_only[:,:,1] = 0  # Remove green
        red_only[:,:,2] = 0  # Remove blue
        return red_only
    
    elif filter_type == "Invert":
        # Invert colors
        return 255 - img_array
    
    else:  # Original
        return img_array

# %%
demo4 = gr.Interface(
    fn=simple_image_filter,
    inputs=[
        gr.Image(type="pil", label="Upload Image"),
        gr.Radio(["Original", "Grayscale", "Red Channel", "Invert"], 
                value="Original", label="Filter")
    ],
    outputs=gr.Image(label="Filtered Image"),
    title="Simple Image Filter"
)
demo4.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * Running on public URL: https://7d033d2345c444aa80.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7d033d2345c444aa80.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/uvicorn/protocols/http/httptools_impl.py", line 409, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.scope, self.receive, self.send
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/applications.py", line 1134, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/applications.py", line 113, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/gradio/brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/gradio/route_utils.py", line 882, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/middleware/exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/routing.py", line 124, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/routing.py", line 110, in app
#     response = await f(request)
#                ^^^^^^^^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/routing.py", line 390, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#     )
#     ^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/fastapi/routing.py", line 289, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/gradio/routes.py", line 1671, in get_upload_progress
#     await asyncio.wait_for(
#         file_upload_statuses.is_tracked(upload_id), timeout=3
#     )
#   File "/Users/rajesh/miniconda3/lib/python3.13/asyncio/tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/site-packages/gradio/route_utils.py", line 528, in is_tracked
#     return await self._signals[upload_id].wait()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/asyncio/locks.py", line 210, in wait
#     fut = self._get_loop().create_future()
#           ~~~~~~~~~~~~~~^^
#   File "/Users/rajesh/miniconda3/lib/python3.13/asyncio/mixins.py", line 20, in _get_loop
#     raise RuntimeError(f'{self!r} is bound to a different event loop')
# RuntimeError: <asyncio.locks.Event object at 0x12cd942f0 [unset]> is bound to a different event loop
