# %%
2+2
# Out:
# 4

# %% [markdown]
# **Contents**
#
# 1. Setup
# 2. Basic Call
# 3. Being clear a direct (before/after)
# 4. Role prompting (system prompts)

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/rajesh/miniconda3/lib/python3.13/site-packages (1.0.1)

# %%
import os
import json
from litellm import completion

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
MODEL = "openai/gpt-4o-mini"
API_KEY = os.getenv("OPENAI_API_KEY")
print("Using model:", MODEL)
# Out:
# Using model: openai/gpt-4o-mini

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a computer program, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    max_tokens=100,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    temperature=1,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    temperature=1,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a program, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    temperature=0,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    temperature=0,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
response = completion(
    model=MODEL,
    messages=[
        {"role": "user", "content": "Hello, how are you?"}
    ],
    api_key=API_KEY,
    # temperature=0,
    top_p=0.5,

)
print(response.choices[0].message.content)
# Out:
# Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
def ask(model, prompt,temperature=0.2, max_tokens=1024, **kwargs):
    response = completion(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        api_key=API_KEY,
        temperature=temperature,
        max_tokens=max_tokens,
        **kwargs,
    )
    return response.choices[0].message.content

# %%
MODEL
# Out:
# 'openai/gpt-4o-mini'

# %%
ask(model=MODEL, prompt="Hello, how are you?", temperature=0.5, max_tokens=10)
# Out:
# "Hello! I'm just a computer program, so I"

# %%
ask(model=MODEL, prompt="Hello, how are you?", temperature=0.5, max_tokens=100)
# Out:
# "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?"
